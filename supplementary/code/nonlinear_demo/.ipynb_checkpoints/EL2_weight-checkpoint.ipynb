# %% [markdown]
# ### This is demo notebook for Embedding Learning code.
# Run under: Python3.6, TF1.14.0, gensim3.4.0, numpy1.16.1
#
# This demo is based on tuning lam2 in [500, 800] and 5 times reps, the performance can be further improved by more accurate grid searching for lam2.

# %%
import sys
sys.executable
# Out:
# '/home/ben/pyenv/EL/bin/python3.6'

# %%
from data_load_w2v import load_data
import numpy as np
import tensorflow as tf
from scipy.spatial.distance import pdist, squareform
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split
import funs
from sklearn.preprocessing import normalize
from scipy import sparse
import random
from sklearn import preprocessing
from main_EL1_genX import EL_genX
from gen_weight import load_weight
# Out:
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
## load data
p, d = 300, 2000
# weight = sparse.load_npz('weight_matrix.npz')
embedding_method = 'googlenews'
y = np.load('googlenew_y.npy')
input_data = sparse.load_npz('input_X.npz')
input_data = normalize(input_data, axis=1, norm='l1')
# d = len(dict_emb)

senti_data = funs.P_data()
senti_data.data = input_data
senti_data.id = np.arange(len(y))
senti_data.y = y

senti_data.weight = load_weight(a=6, b=14, c=7, d=23)
senti_data.weight = normalize(senti_data.weight, axis=1, norm='l1')
P = sparse.eye(d) - senti_data.weight
P = P.T.dot(P)
# Out:
# [0.15351506456241032, 697]

# %%
echo_perf=[]
for j in range(5):
    train, valid, test = senti_data.split_data()
    echo_cv = []
    word_base_mat, acc_valid_orig, acc_test_orig = EL_genX(train, valid, test, p=p)
    echo_cv.append([0., acc_valid_orig, acc_test_orig])
    init_X = input_data.dot(word_base_mat)
    echo = funs.GEC(d=d, p=p)

    # Parameters
    learning_rate = .005
    num_steps = 500
    display_step = 5

    # Network Parameters
    n_hidden = 128
    num_input = p
    num_classes = 1

    X = tf.placeholder("float", [None, num_input])
    Y = tf.placeholder("float", [None, num_classes])

    A = {
        'h1': tf.Variable(tf.random_normal([num_input, n_hidden])),
        'h2': tf.Variable(tf.random_normal([n_hidden, n_hidden])),
        'h3': tf.Variable(tf.random_normal([n_hidden, n_hidden])),
        'out': tf.Variable(tf.random_normal([n_hidden, num_classes]))
    }

    b = {
        'b1': tf.Variable(tf.random_normal([n_hidden])),
        'b2': tf.Variable(tf.random_normal([n_hidden])),
        'b3': tf.Variable(tf.random_normal([n_hidden])),
        'out': tf.Variable(tf.random_normal([num_classes]))
    }

    # Create model# Creat 
    def neural_net(x):
        # Hidden fully connected layer
        layer_1 = tf.add(tf.matmul(x, A['h1']), b['b1'])
        layer_1 = tf.nn.relu(layer_1)
        layer_2 = tf.nn.relu(tf.add(tf.matmul(layer_1, A['h2']), b['b2']))
        layer_3 = tf.nn.relu(tf.add(tf.matmul(layer_2, A['h3']), b['b3']))
        out_layer = tf.matmul(layer_2, A['out']) + b['out']
        return out_layer
#     lam_range = [1e-3, 1., 10, 100, 500, 800, 1000, 1500, 1800, 2000]
    # lam_range = 10**np.arange(-3.,4.,.5)
    lam_range = [100, 500, 800]
    # for lam1 in lam_range:
    for lam2 in lam_range:
        print("training for lam2: %s" %lam2)
        echo.X = np.copy(init_X)
        # Define loss and optimizer
        logits = neural_net(X)
        loss_op = tf.reduce_mean(tf.losses.hinge_loss(logits=logits, labels=Y))
        loss_op = tf.reduce_mean(loss_op)
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
        train_op = optimizer.minimize(loss_op)
        var_grad = tf.gradients(loss_op, [b['b1']])[0]

        # Evaluate model (with test logits, for dropout to be disabled)
        predicted_class = tf.greater(logits,0.0)
        correct_pred = tf.equal(predicted_class, tf.equal(Y,1.0))
        # correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(Y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

        # Initialize the variables (i.e. assign their default value)
        init = tf.global_variables_initializer()

        # Start training
        with tf.Session() as sess:
            opt_valid = 0.
        # Run the initializer
            sess.run(init)
            # learning_rate_embed0 = .1/lam2
            learning_rate_embed0 = learning_rate/100.
            for step in range(1, num_steps+1):
                ## Embedding block
                learning_rate_embed = learning_rate_embed0/np.sqrt(step)
                A1 = sess.run(A['h1']).T
                delta_mat = np.zeros((d, n_hidden))
                for i in range(len(train.id)):
                    id_tmp = train.id[i]
                    X_grad_tmp, y_grad_tmp = echo.X[id_tmp].reshape((1,p)), train.y[i].reshape((1,1))
                    delta_mat[id_tmp,:] = sess.run(var_grad, feed_dict={X: X_grad_tmp, Y: y_grad_tmp})
                # echo.X -= learning_rate_embed * (delta_mat.dot(A1)/len(train.id) + lam2 * P.dot(echo.X))
                echo.X -= learning_rate_embed * lam2 * P.dot(echo.X)
                # echo.X -= learning_rate_embed * (delta_mat.dot(A1)/len(train.id) + lam2 * (echo.X - init_X))
                ## Learning block
                X_tmp, y_tmp = echo.X[train.id], train.y[:, np.newaxis]
                sess.run(train_op, feed_dict={X: X_tmp, Y: y_tmp})
                acc_valid = sess.run(accuracy, feed_dict={X: echo.X[valid.id], Y: valid.y[:, np.newaxis]})

                if step % display_step == 0 or step == 1:
                # Calculate batch loss and accuracy
                    loss, acc = sess.run([loss_op, accuracy], feed_dict={X: X_tmp, Y: y_tmp})
                    print("Step " + str(step) + ", Loss= " + \
                        "{:.4f}".format(loss) + ", Train Accuracy= " + \
                        "{:.3f}".format(acc) + ", Valid Accuracy= " + \
                        "{:.3f}".format(acc_valid))
                    if acc > .96:
                        break
            print("Optimization Finished!")
            # Calculate accuracy for PPI test
            acc_test = sess.run(accuracy, feed_dict={X: echo.X[test.id], Y: test.y[:, np.newaxis]})
            print("Testing Accuracy:", acc_test)
        echo_cv.append([lam2, acc_valid, acc_test])
    echo_cv = np.array(echo_cv)
    echo_perf_tmp = echo_cv[np.argmax(echo_cv[:,1]), 2]
    print('-----------------------------')
    print("perform for %s iteration: %.3f" %(j, echo_perf_tmp))
    echo_perf.append(echo_perf_tmp)
# Out:
# WARNING:tensorflow:From /home/ben/MEGA/github/embedding-learning/supplementary/code/nonlinear_demo/main_EL1_genX.py:29: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/ben/MEGA/github/embedding-learning/supplementary/code/nonlinear_demo/main_EL1_genX.py:35: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /home/ben/MEGA/github/embedding-learning/supplementary/code/nonlinear_demo/main_EL1_genX.py:61: The name tf.losses.hinge_loss is deprecated. Please use tf.compat.v1.losses.hinge_loss instead.
#
# WARNING:tensorflow:From /home/ben/pyenv/EL/lib/python3.6/site-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ben/MEGA/github/embedding-learning/supplementary/code/nonlinear_demo/main_EL1_genX.py:64: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/ben/MEGA/github/embedding-learning/supplementary/code/nonlinear_demo/main_EL1_genX.py:75: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/ben/MEGA/github/embedding-learning/supplementary/code/nonlinear_demo/main_EL1_genX.py:78: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# training for lam2: 100
# Step 1, Loss= 18.6660, Train Accuracy= 0.533, Valid Accuracy= 0.510
# Step 5, Loss= 20.7831, Train Accuracy= 0.545, Valid Accuracy= 0.575
# Step 10, Loss= 13.0334, Train Accuracy= 0.768, Valid Accuracy= 0.585
# Step 15, Loss= 5.7440, Train Accuracy= 0.758, Valid Accuracy= 0.690
# Step 20, Loss= 2.0545, Train Accuracy= 0.898, Valid Accuracy= 0.748
# Step 25, Loss= 2.0589, Train Accuracy= 0.922, Valid Accuracy= 0.723
# Step 30, Loss= 1.1925, Train Accuracy= 0.925, Valid Accuracy= 0.757
# Step 35, Loss= 0.6634, Train Accuracy= 0.957, Valid Accuracy= 0.767
# Step 40, Loss= 0.5419, Train Accuracy= 0.969, Valid Accuracy= 0.765
# Optimization Finished!
# Testing Accuracy: 0.76666665
# training for lam2: 500
# Step 1, Loss= 20.3662, Train Accuracy= 0.624, Valid Accuracy= 0.527
# Step 5, Loss= 23.8057, Train Accuracy= 0.495, Valid Accuracy= 0.540
# Step 10, Loss= 4.0906, Train Accuracy= 0.757, Valid Accuracy= 0.680
# Step 15, Loss= 6.6619, Train Accuracy= 0.824, Valid Accuracy= 0.620
# Step 20, Loss= 2.2769, Train Accuracy= 0.865, Valid Accuracy= 0.772
# Step 25, Loss= 2.8467, Train Accuracy= 0.838, Valid Accuracy= 0.757
# Step 30, Loss= 1.3020, Train Accuracy= 0.926, Valid Accuracy= 0.760
# Step 35, Loss= 1.4344, Train Accuracy= 0.937, Valid Accuracy= 0.745
# Step 40, Loss= 0.7400, Train Accuracy= 0.947, Valid Accuracy= 0.783
# Step 45, Loss= 0.7107, Train Accuracy= 0.939, Valid Accuracy= 0.767
# Step 50, Loss= 0.4132, Train Accuracy= 0.962, Valid Accuracy= 0.777
# Optimization Finished!
# Testing Accuracy: 0.76
# training for lam2: 800
# Step 1, Loss= 102.4108, Train Accuracy= 0.503, Valid Accuracy= 0.442
# Step 5, Loss= 48.3351, Train Accuracy= 0.484, Valid Accuracy= 0.538
# Step 10, Loss= 37.6789, Train Accuracy= 0.485, Valid Accuracy= 0.538
# Step 15, Loss= 6.4494, Train Accuracy= 0.759, Valid Accuracy= 0.675
# Step 20, Loss= 6.0470, Train Accuracy= 0.810, Valid Accuracy= 0.688
# Step 25, Loss= 6.9719, Train Accuracy= 0.683, Valid Accuracy= 0.645
# Step 30, Loss= 3.4952, Train Accuracy= 0.800, Valid Accuracy= 0.745
# Step 35, Loss= 3.0090, Train Accuracy= 0.892, Valid Accuracy= 0.725
# Step 40, Loss= 1.9420, Train Accuracy= 0.909, Valid Accuracy= 0.748
# Step 45, Loss= 1.9350, Train Accuracy= 0.870, Valid Accuracy= 0.757
# Step 50, Loss= 1.5249, Train Accuracy= 0.891, Valid Accuracy= 0.760
# Step 55, Loss= 1.2568, Train Accuracy= 0.928, Valid Accuracy= 0.760
# Step 60, Loss= 0.9864, Train Accuracy= 0.930, Valid Accuracy= 0.767
# Step 65, Loss= 0.8741, Train Accuracy= 0.927, Valid Accuracy= 0.762
# Step 70, Loss= 0.7155, Train Accuracy= 0.935, Valid Accuracy= 0.745
# Step 75, Loss= 0.5810, Train Accuracy= 0.945, Valid Accuracy= 0.757
# Step 80, Loss= 0.4990, Train Accuracy= 0.949, Valid Accuracy= 0.760
# Step 85, Loss= 0.4296, Train Accuracy= 0.953, Valid Accuracy= 0.755
# Step 90, Loss= 0.3690, Train Accuracy= 0.959, Valid Accuracy= 0.757
# Step 95, Loss= 0.3161, Train Accuracy= 0.966, Valid Accuracy= 0.752
# Optimization Finished!
# Testing Accuracy: 0.7816667
# -----------------------------
# perform for 0 iteration: 0.792
# training for lam2: 100
# Step 1, Loss= 13.6186, Train Accuracy= 0.668, Valid Accuracy= 0.553
# Step 5, Loss= 3.6735, Train Accuracy= 0.832, Valid Accuracy= 0.660
# Step 10, Loss= 2.3951, Train Accuracy= 0.856, Valid Accuracy= 0.685
# Step 15, Loss= 1.1154, Train Accuracy= 0.950, Valid Accuracy= 0.762
# Step 20, Loss= 0.7768, Train Accuracy= 0.960, Valid Accuracy= 0.777
# Step 25, Loss= 0.7991, Train Accuracy= 0.948, Valid Accuracy= 0.752
# Step 30, Loss= 0.5230, Train Accuracy= 0.973, Valid Accuracy= 0.770
# Optimization Finished!
# Testing Accuracy: 0.75
# training for lam2: 500
# Step 1, Loss= 82.5933, Train Accuracy= 0.508, Valid Accuracy= 0.498
# Step 5, Loss= 43.5004, Train Accuracy= 0.493, Valid Accuracy= 0.498
# Step 10, Loss= 31.5975, Train Accuracy= 0.502, Valid Accuracy= 0.498
# Step 15, Loss= 8.4713, Train Accuracy= 0.756, Valid Accuracy= 0.637
# Step 20, Loss= 7.0979, Train Accuracy= 0.786, Valid Accuracy= 0.675
# Step 25, Loss= 6.8501, Train Accuracy= 0.710, Valid Accuracy= 0.620
# Step 30, Loss= 3.6463, Train Accuracy= 0.797, Valid Accuracy= 0.675
# Step 35, Loss= 2.9515, Train Accuracy= 0.891, Valid Accuracy= 0.743
# Step 40, Loss= 1.3960, Train Accuracy= 0.907, Valid Accuracy= 0.755
# Step 45, Loss= 1.5808, Train Accuracy= 0.890, Valid Accuracy= 0.728
# Step 50, Loss= 0.7908, Train Accuracy= 0.942, Valid Accuracy= 0.752
# Step 55, Loss= 0.8327, Train Accuracy= 0.952, Valid Accuracy= 0.770
# Step 60, Loss= 0.6977, Train Accuracy= 0.934, Valid Accuracy= 0.760
# Step 65, Loss= 0.5108, Train Accuracy= 0.955, Valid Accuracy= 0.755
# Step 70, Loss= 0.4586, Train Accuracy= 0.962, Valid Accuracy= 0.755
# Optimization Finished!
# Testing Accuracy: 0.81166667
# training for lam2: 800
# Step 1, Loss= 43.1672, Train Accuracy= 0.493, Valid Accuracy= 0.498
# Step 5, Loss= 14.3248, Train Accuracy= 0.585, Valid Accuracy= 0.623
# Step 10, Loss= 8.0475, Train Accuracy= 0.592, Valid Accuracy= 0.553
# Step 15, Loss= 5.2629, Train Accuracy= 0.800, Valid Accuracy= 0.743
# Step 20, Loss= 2.7950, Train Accuracy= 0.813, Valid Accuracy= 0.728
# Step 25, Loss= 1.7952, Train Accuracy= 0.872, Valid Accuracy= 0.788
# Step 30, Loss= 1.7503, Train Accuracy= 0.912, Valid Accuracy= 0.803
# Step 35, Loss= 1.2141, Train Accuracy= 0.891, Valid Accuracy= 0.783
# Step 40, Loss= 0.8206, Train Accuracy= 0.933, Valid Accuracy= 0.808
# Step 45, Loss= 0.6234, Train Accuracy= 0.938, Valid Accuracy= 0.808
# Step 50, Loss= 0.4903, Train Accuracy= 0.942, Valid Accuracy= 0.798
# Step 55, Loss= 0.3622, Train Accuracy= 0.961, Valid Accuracy= 0.798
# Optimization Finished!
# Testing Accuracy: 0.795
# -----------------------------
# perform for 1 iteration: 0.795
# training for lam2: 100
# Step 1, Loss= 138.4873, Train Accuracy= 0.486, Valid Accuracy= 0.535
# Step 5, Loss= 31.4099, Train Accuracy= 0.517, Valid Accuracy= 0.465
# Step 10, Loss= 42.6292, Train Accuracy= 0.513, Valid Accuracy= 0.465
# Step 15, Loss= 14.5734, Train Accuracy= 0.556, Valid Accuracy= 0.500
# Step 20, Loss= 14.9714, Train Accuracy= 0.661, Valid Accuracy= 0.658
# Step 25, Loss= 4.4102, Train Accuracy= 0.739, Valid Accuracy= 0.637
# Step 30, Loss= 5.3669, Train Accuracy= 0.717, Valid Accuracy= 0.632
# Step 35, Loss= 2.5611, Train Accuracy= 0.869, Valid Accuracy= 0.743
# Step 40, Loss= 2.1093, Train Accuracy= 0.886, Valid Accuracy= 0.757
# Step 45, Loss= 1.7672, Train Accuracy= 0.882, Valid Accuracy= 0.720
# Step 50, Loss= 1.1768, Train Accuracy= 0.912, Valid Accuracy= 0.755
# Step 55, Loss= 1.0433, Train Accuracy= 0.929, Valid Accuracy= 0.777
# Step 60, Loss= 0.7281, Train Accuracy= 0.942, Valid Accuracy= 0.772
# Step 65, Loss= 0.6083, Train Accuracy= 0.951, Valid Accuracy= 0.772
# Step 70, Loss= 0.5142, Train Accuracy= 0.955, Valid Accuracy= 0.783
# Step 75, Loss= 0.3989, Train Accuracy= 0.960, Valid Accuracy= 0.772
# Step 80, Loss= 0.3136, Train Accuracy= 0.971, Valid Accuracy= 0.783
# Optimization Finished!
# Testing Accuracy: 0.78833336
# training for lam2: 500
# Step 1, Loss= 22.6577, Train Accuracy= 0.396, Valid Accuracy= 0.400
# Step 5, Loss= 16.9139, Train Accuracy= 0.512, Valid Accuracy= 0.465
# Step 10, Loss= 9.9205, Train Accuracy= 0.625, Valid Accuracy= 0.630
# Step 15, Loss= 5.8926, Train Accuracy= 0.672, Valid Accuracy= 0.605
# Step 20, Loss= 3.6285, Train Accuracy= 0.793, Valid Accuracy= 0.700
# Step 25, Loss= 2.2251, Train Accuracy= 0.812, Valid Accuracy= 0.707
# Step 30, Loss= 1.4576, Train Accuracy= 0.890, Valid Accuracy= 0.750
# Step 35, Loss= 0.9679, Train Accuracy= 0.899, Valid Accuracy= 0.728
# Step 40, Loss= 0.6593, Train Accuracy= 0.928, Valid Accuracy= 0.762
# Step 45, Loss= 0.4492, Train Accuracy= 0.940, Valid Accuracy= 0.752
# Step 50, Loss= 0.3090, Train Accuracy= 0.962, Valid Accuracy= 0.780
# Optimization Finished!
# Testing Accuracy: 0.77
# training for lam2: 800
# Step 1, Loss= 15.8961, Train Accuracy= 0.525, Valid Accuracy= 0.512
# Step 5, Loss= 8.2801, Train Accuracy= 0.665, Valid Accuracy= 0.618
# Step 10, Loss= 4.0497, Train Accuracy= 0.764, Valid Accuracy= 0.652
# Step 15, Loss= 2.0658, Train Accuracy= 0.852, Valid Accuracy= 0.733
# Step 20, Loss= 1.1667, Train Accuracy= 0.905, Valid Accuracy= 0.772
# Step 25, Loss= 0.7553, Train Accuracy= 0.909, Valid Accuracy= 0.757
# Step 30, Loss= 0.4311, Train Accuracy= 0.952, Valid Accuracy= 0.770
# Step 35, Loss= 0.2739, Train Accuracy= 0.961, Valid Accuracy= 0.762
# Optimization Finished!
# Testing Accuracy: 0.7783333
# -----------------------------
# perform for 2 iteration: 0.777
# training for lam2: 100
# Step 1, Loss= 21.4911, Train Accuracy= 0.471, Valid Accuracy= 0.565
# Step 5, Loss= 32.0676, Train Accuracy= 0.503, Valid Accuracy= 0.477
# Step 10, Loss= 14.0546, Train Accuracy= 0.674, Valid Accuracy= 0.685
# Step 15, Loss= 5.8128, Train Accuracy= 0.740, Valid Accuracy= 0.683
# Step 20, Loss= 4.3571, Train Accuracy= 0.798, Valid Accuracy= 0.690
# Step 25, Loss= 3.9934, Train Accuracy= 0.884, Valid Accuracy= 0.785
# Step 30, Loss= 2.0693, Train Accuracy= 0.880, Valid Accuracy= 0.730
# Step 35, Loss= 1.5075, Train Accuracy= 0.916, Valid Accuracy= 0.740
# Step 40, Loss= 1.3005, Train Accuracy= 0.944, Valid Accuracy= 0.765
# Step 45, Loss= 0.7647, Train Accuracy= 0.941, Valid Accuracy= 0.743
# Step 50, Loss= 0.4705, Train Accuracy= 0.960, Valid Accuracy= 0.752
# Step 55, Loss= 0.2804, Train Accuracy= 0.974, Valid Accuracy= 0.750
# Optimization Finished!
# Testing Accuracy: 0.765
# training for lam2: 500
# Step 1, Loss= 98.2254, Train Accuracy= 0.501, Valid Accuracy= 0.527
# Step 5, Loss= 38.5272, Train Accuracy= 0.502, Valid Accuracy= 0.480
# Step 10, Loss= 34.0148, Train Accuracy= 0.501, Valid Accuracy= 0.480
# Step 15, Loss= 4.8400, Train Accuracy= 0.712, Valid Accuracy= 0.618
# Step 20, Loss= 8.6474, Train Accuracy= 0.772, Valid Accuracy= 0.683
# Step 25, Loss= 4.6195, Train Accuracy= 0.716, Valid Accuracy= 0.605
# Step 30, Loss= 3.3078, Train Accuracy= 0.780, Valid Accuracy= 0.655
# Step 35, Loss= 2.5884, Train Accuracy= 0.899, Valid Accuracy= 0.755
# Step 40, Loss= 1.6999, Train Accuracy= 0.902, Valid Accuracy= 0.760
# Step 45, Loss= 1.7025, Train Accuracy= 0.870, Valid Accuracy= 0.705
# Step 50, Loss= 1.0948, Train Accuracy= 0.910, Valid Accuracy= 0.750
# Step 55, Loss= 1.0156, Train Accuracy= 0.929, Valid Accuracy= 0.767
# Step 60, Loss= 0.7741, Train Accuracy= 0.924, Valid Accuracy= 0.752
# Step 65, Loss= 0.6050, Train Accuracy= 0.938, Valid Accuracy= 0.765
# Step 70, Loss= 0.5271, Train Accuracy= 0.943, Valid Accuracy= 0.762
# Step 75, Loss= 0.4464, Train Accuracy= 0.947, Valid Accuracy= 0.765
# Step 80, Loss= 0.3687, Train Accuracy= 0.954, Valid Accuracy= 0.765
# Step 85, Loss= 0.3095, Train Accuracy= 0.957, Valid Accuracy= 0.765
# Step 90, Loss= 0.2592, Train Accuracy= 0.962, Valid Accuracy= 0.762
# Optimization Finished!
# Testing Accuracy: 0.8066667
# training for lam2: 800
# Step 1, Loss= 15.8211, Train Accuracy= 0.494, Valid Accuracy= 0.485
# Step 5, Loss= 9.6043, Train Accuracy= 0.552, Valid Accuracy= 0.493
# Step 10, Loss= 4.1789, Train Accuracy= 0.784, Valid Accuracy= 0.660
# Step 15, Loss= 3.5086, Train Accuracy= 0.743, Valid Accuracy= 0.608
# Step 20, Loss= 2.5317, Train Accuracy= 0.868, Valid Accuracy= 0.730
# Step 25, Loss= 1.3969, Train Accuracy= 0.883, Valid Accuracy= 0.715
# Step 30, Loss= 1.1095, Train Accuracy= 0.894, Valid Accuracy= 0.725
# Step 35, Loss= 0.9241, Train Accuracy= 0.930, Valid Accuracy= 0.748
# Step 40, Loss= 0.6092, Train Accuracy= 0.933, Valid Accuracy= 0.723
# Step 45, Loss= 0.4098, Train Accuracy= 0.954, Valid Accuracy= 0.723
# Step 50, Loss= 0.3183, Train Accuracy= 0.960, Valid Accuracy= 0.733
# Step 55, Loss= 0.2684, Train Accuracy= 0.964, Valid Accuracy= 0.715
# Optimization Finished!
# Testing Accuracy: 0.7816667
# -----------------------------
# perform for 3 iteration: 0.802
# training for lam2: 100
# Step 1, Loss= 29.3083, Train Accuracy= 0.475, Valid Accuracy= 0.527
# Step 5, Loss= 13.3004, Train Accuracy= 0.527, Valid Accuracy= 0.545
# Step 10, Loss= 10.4160, Train Accuracy= 0.589, Valid Accuracy= 0.610
# Step 15, Loss= 6.0413, Train Accuracy= 0.748, Valid Accuracy= 0.717
# Step 20, Loss= 4.6215, Train Accuracy= 0.773, Valid Accuracy= 0.745
# Step 25, Loss= 3.6788, Train Accuracy= 0.785, Valid Accuracy= 0.748
# Step 30, Loss= 2.9037, Train Accuracy= 0.857, Valid Accuracy= 0.757
# Step 35, Loss= 2.3115, Train Accuracy= 0.829, Valid Accuracy= 0.748
# Step 40, Loss= 1.7978, Train Accuracy= 0.895, Valid Accuracy= 0.770
# Step 45, Loss= 1.3406, Train Accuracy= 0.884, Valid Accuracy= 0.755
# Step 50, Loss= 1.0446, Train Accuracy= 0.907, Valid Accuracy= 0.762
# Step 55, Loss= 0.8761, Train Accuracy= 0.926, Valid Accuracy= 0.772
# Step 60, Loss= 0.6497, Train Accuracy= 0.938, Valid Accuracy= 0.770
# Step 65, Loss= 0.5148, Train Accuracy= 0.943, Valid Accuracy= 0.770
# Step 70, Loss= 0.3941, Train Accuracy= 0.956, Valid Accuracy= 0.785
# Step 75, Loss= 0.3019, Train Accuracy= 0.962, Valid Accuracy= 0.790
# Optimization Finished!
# Testing Accuracy: 0.77166665
# training for lam2: 500
# Step 1, Loss= 27.1110, Train Accuracy= 0.464, Valid Accuracy= 0.488
# Step 5, Loss= 26.9622, Train Accuracy= 0.479, Valid Accuracy= 0.527
# Step 10, Loss= 14.3693, Train Accuracy= 0.663, Valid Accuracy= 0.637
# Step 15, Loss= 11.2388, Train Accuracy= 0.584, Valid Accuracy= 0.590
# Step 20, Loss= 7.8421, Train Accuracy= 0.773, Valid Accuracy= 0.720
# Step 25, Loss= 5.4205, Train Accuracy= 0.736, Valid Accuracy= 0.670
# Step 30, Loss= 3.5549, Train Accuracy= 0.830, Valid Accuracy= 0.750
# Step 35, Loss= 2.9309, Train Accuracy= 0.849, Valid Accuracy= 0.752
# Step 40, Loss= 2.5300, Train Accuracy= 0.833, Valid Accuracy= 0.733
# Step 45, Loss= 2.0961, Train Accuracy= 0.873, Valid Accuracy= 0.780
# Step 50, Loss= 1.7883, Train Accuracy= 0.858, Valid Accuracy= 0.762
# Step 55, Loss= 1.4328, Train Accuracy= 0.889, Valid Accuracy= 0.777
# Step 60, Loss= 1.2545, Train Accuracy= 0.897, Valid Accuracy= 0.780
# Step 65, Loss= 1.1341, Train Accuracy= 0.898, Valid Accuracy= 0.775
# Step 70, Loss= 0.9683, Train Accuracy= 0.914, Valid Accuracy= 0.775
# Step 75, Loss= 0.8788, Train Accuracy= 0.913, Valid Accuracy= 0.777
# Step 80, Loss= 0.7640, Train Accuracy= 0.929, Valid Accuracy= 0.783
# Step 85, Loss= 0.6852, Train Accuracy= 0.931, Valid Accuracy= 0.775
# Step 90, Loss= 0.6012, Train Accuracy= 0.942, Valid Accuracy= 0.777
# Step 95, Loss= 0.5380, Train Accuracy= 0.945, Valid Accuracy= 0.783
# Step 100, Loss= 0.4871, Train Accuracy= 0.954, Valid Accuracy= 0.785
# Step 105, Loss= 0.4388, Train Accuracy= 0.956, Valid Accuracy= 0.790
# Step 110, Loss= 0.3907, Train Accuracy= 0.962, Valid Accuracy= 0.793
# Optimization Finished!
# Testing Accuracy: 0.8016667
# training for lam2: 800
# Step 1, Loss= 20.6473, Train Accuracy= 0.482, Valid Accuracy= 0.512
# Step 5, Loss= 7.8462, Train Accuracy= 0.576, Valid Accuracy= 0.562
# Step 10, Loss= 5.3314, Train Accuracy= 0.654, Valid Accuracy= 0.623
# Step 15, Loss= 2.9722, Train Accuracy= 0.773, Valid Accuracy= 0.723
# Step 20, Loss= 2.5365, Train Accuracy= 0.802, Valid Accuracy= 0.745
# Step 25, Loss= 2.4160, Train Accuracy= 0.790, Valid Accuracy= 0.712
# Step 30, Loss= 2.1314, Train Accuracy= 0.843, Valid Accuracy= 0.775
# Step 35, Loss= 1.7442, Train Accuracy= 0.827, Valid Accuracy= 0.730
# Step 40, Loss= 1.3728, Train Accuracy= 0.854, Valid Accuracy= 0.775
# Step 45, Loss= 1.0781, Train Accuracy= 0.861, Valid Accuracy= 0.752
# Step 50, Loss= 0.9188, Train Accuracy= 0.873, Valid Accuracy= 0.752
# Step 55, Loss= 0.7929, Train Accuracy= 0.880, Valid Accuracy= 0.760
# Step 60, Loss= 0.6682, Train Accuracy= 0.897, Valid Accuracy= 0.765
# Step 65, Loss= 0.5608, Train Accuracy= 0.904, Valid Accuracy= 0.757
# Step 70, Loss= 0.4781, Train Accuracy= 0.912, Valid Accuracy= 0.752
# Step 75, Loss= 0.4052, Train Accuracy= 0.928, Valid Accuracy= 0.745
# Step 80, Loss= 0.3545, Train Accuracy= 0.934, Valid Accuracy= 0.748
# Step 85, Loss= 0.3195, Train Accuracy= 0.939, Valid Accuracy= 0.752
# Step 90, Loss= 0.2741, Train Accuracy= 0.943, Valid Accuracy= 0.755
# Step 95, Loss= 0.2563, Train Accuracy= 0.937, Valid Accuracy= 0.765
# Step 100, Loss= 0.2471, Train Accuracy= 0.944, Valid Accuracy= 0.762
# Step 105, Loss= 0.2543, Train Accuracy= 0.936, Valid Accuracy= 0.770
# Step 110, Loss= 0.1853, Train Accuracy= 0.959, Valid Accuracy= 0.762
# Step 115, Loss= 0.1526, Train Accuracy= 0.961, Valid Accuracy= 0.767
# Optimization Finished!
# Testing Accuracy: 0.7583333
# -----------------------------
# perform for 4 iteration: 0.782

# %%
echo_perf = np.array(echo_perf)
print('echo perf: %.3f(%.3f)' %(1.-echo_perf.mean(), echo_perf.std()/np.sqrt(5)))
# Out:
# echo perf: 0.211(0.004)
